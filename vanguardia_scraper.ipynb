# %%
import importlib
import la_vanguardia
importlib.reload(la_vanguardia)
from la_vanguardia import obtener_noticias_vanguardia
import json
from datetime import datetime

resultados_lv = obtener_noticias_vanguardia(num_por_categoria=5)    
resultados_lv[0]
# Out:
# {'Link': 'https://www.lavanguardia.com/internacional/20260427/11523867/fallecen-14-personas-accidente-avioneta-sudan-sur.html',
#  'Periódico': 'La Vanguardia',
#  'Fecha': '2026-04-27',
#  'Título': 'Fallecen 14 personas en un accidente de avioneta en Sudán del Sur',
#  'Subtítulo': 'La Autoridad de Aviación Civil del país africano confirma que la&nbsp;avioneta se ha estrellado sin supervivientes cerca de la capital, Yuba',
#  'Categoría': 'Internacional',
# ...
