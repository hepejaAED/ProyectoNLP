# %% [markdown]
# ## Notebook Scrappeo 20minutos (https://www.20minutos.es/rss)

# %%
import feedparser

# URL del feed RSS de 20minutos (Internacional)
url = 'https://www.20minutos.es/rss'

# Analiza el contenido del feed
feed = feedparser.parse(url)

# %%
import time
from bs4 import BeautifulSoup

noticias = []

for entry in feed.entries:
    if "content" in entry.keys():
        noticia = {
        "Link": entry.link,
        "Periódico": "20minutos",
        "Fecha": time.strftime("%Y-%m-%d", entry.published_parsed),
        "Título": entry.title,
        "Resumen": entry.summary,
        "Categoría": entry.category,
        "Contenido": BeautifulSoup(entry.content[0].value, 'html.parser').text
        }

        noticias.append(noticia)
    else:
        print(f"La noticia {entry.link} no tiene contenido")
# Out:
# La noticia https://www.20minutos.es/andalucia/sevilla/grave-cogida-roca-rey-maestranza-sevilla-corrida-toros_6962177_1.html no tiene contenido
# La noticia https://www.20minutos.es/branded-content/escuela-energia-talleres-para-ser-mas-eficientes-ahorrar_6957493_4.html no tiene contenido
# La noticia https://www.20minutos.es/gonzoo/estas-personas-pidieron-cosas-por-internet-pero-se-arrepintieron-cuanto-que-llegaron_6959048_1.html no tiene contenido
# La noticia https://www.20minutos.es/mujer/moda/los-mejores-looks-valentino-las-celebrities_6958581_1.html no tiene contenido
# La noticia https://www.20minutos.es/gente/celebrities-que-nacieron-23-abril-dia-libro_6957556_1.html no tiene contenido

# %% [markdown]
# Guardamos las noticias extraídas en un archivo `.json` con el nombre `20minutos.json`.

# %%
import json

with open("data/20minutos.json", 'w', encoding = 'utf-8') as archivo:
    json.dump(noticias, archivo, indent = 4, ensure_ascii = False)
